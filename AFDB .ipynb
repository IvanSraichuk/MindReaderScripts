# %%
import wfdb
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
q = 11000
record = wfdb.rdrecord('D:/phd/mit-bih-atrial-fibrillation-database-1.0.0/files/04126', sampfrom=q, sampto=q+500) 
annotation = wfdb.rdann('D:/phd/mit-bih-atrial-fibrillation-database-1.0.0/files/04126','atr', sampfrom=q, sampto=q+500, shift_samps=True)

# %%
annotation.__dict__
# Out:
# {'record_name': '04126',
#  'extension': 'atr',
#  'sample': array([388]),
#  'symbol': ['+'],
#  'subtype': array([0]),
#  'chan': array([0]),
#  'num': array([0]),
#  'aux_note': ['(AFIB'],
#  'fs': 250,
#  'label_store': None,
#  'description': None,
#  'custom_labels': None,
#  'contained_labels': None,
#  'ann_len': 1}

# %%
wfdb.plot_wfdb(record=record, annotation=annotation,
               title='Record 04043 from MIT-BIH AFDB'         
               )

# %%
wfdb.plot_wfdb(annotation=annotation, time_units='minutes', title='Record 04043 from MIT-BIH AFDB')

# %%
record = wfdb.rdrecord('D:/phd/mit-bih-atrial-fibrillation-database-1.0.0/files/04126') 
annotation = wfdb.rdann('D:/phd/mit-bih-atrial-fibrillation-database-1.0.0/files/04126','atr')

# %%
wfdb.plot_wfdb(record=record, annotation=annotation,
               title='Record 04043 from MIT-BIH AFDB',
               time_units='minutes'
               )
