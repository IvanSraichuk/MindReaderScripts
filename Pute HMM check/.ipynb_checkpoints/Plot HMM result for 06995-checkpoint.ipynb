# %%
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import neurokit2 as nk
import warnings

# %matplotlib inline

# %%
traceback1 = 'D:\\test\\CheckProjJulia\\out\\06995ECG.txt50P_ECG1_traceback.csv'
traceback2 = 'D:\\test\\CheckProjJulia\\out\\06995ECG.txt25P_ECG1_traceback.csv'
signal_path = 'D:\\test\\CheckProjJulia\\scripts\\06995ECG.txt'

# %%
traceback1 = np.loadtxt(traceback1, dtype=int)
traceback2 = np.loadtxt(traceback2, dtype=int)
arr = np.loadtxt(signal_path, dtype=float)

# %%
colors = ["#0000FF", "#00FF00", "#FF0066", "#FFFF00", "#FF00FF", '#000000' ]
for i in range(4000, len(traceback1), 2000):
    traceback = traceback1[i:i+2000]
    points=[]
    signal = arr[i:i+2000, 0]
    for j in range(len(traceback)):
        if traceback[j] > 1:
            points.append([j, signal[j], colors[traceback[j]]])
    if len(points) > 0:
        plt.figure(figsize=(20, 3))
        plt.plot(signal)
        for i in range(len(points)):
            plt.scatter(points[i][0], points[i][1], color=points[i][2])    
        plt.show()
# Out:
# 4000
# 2000 [[0, -0.3, '#000000'], [1, -0.305, '#000000'], [2, -0.365, '#000000']]
# 6000
# 2000 [[0, -0.34, '#000000'], [1, -0.34, '#000000'], [2, -0.335, '#000000']]
# 8000
# 2000 [[0, -0.22, '#000000'], [1, -0.19, '#000000'], [2, -0.2, '#000000']]
# 10000
# 2000 [[0, -0.3, '#000000'], [1, -0.305, '#000000'], [2, -0.32, '#000000']]
# 12000
# 2000 [[0, -0.22, '#000000'], [1, -0.195, '#000000'], [2, -0.205, '#000000']]
# 14000
# 2000 [[0, -0.105, '#000000'], [1, -0.13, '#000000'], [2, -0.16, '#000000']]
# 16000
# 2000 [[0, -0.33, '#000000'], [1, -0.34, '#000000'], [2, -0.32, '#000000']]
# 18000
# 2000 [[0, -0.425, '#000000'], [1, -0.185, '#000000'], [2, 0.19, '#000000']]
# 20000
# 2000 [[0, -0.405, '#000000'], [1, -0.4, '#000000'], [2, -0.345, '#000000']]
# 22000
# 2000 [[0, -0.285, '#000000'], [1, -0.295, '#000000'], [2, -0.305, '#000000']]
# 24000
# 2000 [[0, 0.12, '#000000'], [1, 0.105, '#000000'], [2, 0.095, '#000000']]
# 26000
# 2000 [[0, -0.405, '#000000'], [1, -0.38, '#000000'], [2, -0.355, '#000000']]

# %%
for i in range(4000, len(traceback2), 2000):
    traceback = traceback2[i:i+2000]
    points=[]
    print(i)
    signal = arr[i:i+2000, 0]
    for j in range(len(traceback)):
        if traceback[j] > 1:
            points.append([j, signal[j], colors[traceback[j]]])
    if len(points) > 0:
        plt.figure(figsize=(20, 4))
        plt.plot(signal)
        for i in range(len(points)):
            plt.scatter(points[i][0], points[i][1], color=points[i][2])    
        plt.show()
